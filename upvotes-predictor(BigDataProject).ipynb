# %%
import numpy as np
import pandas as pd

# %%
trainingData = pd.read_csv("Datasets/trainingset.csv")
#exploring Data:
print(trainingData.isnull().sum())
correlation = trainingData.corr()
correlation.style.background_gradient(cmap='tab20c').set_precision(5)
# Out:
# ID            0
# Tag           0
# Reputation    0
# Answers       0
# Username      0
# Views         0
# Upvotes       0
# dtype: int64
# <style  type="text/css" >
#     #T_3c76b56c_c78f_11eb_bf51_c83dd4f69f64row0_col0 {
#             background-color:  #d9d9d9;
#             color:  #000000;
#         }    #T_3c76b56c_c78f_11eb_bf51_c83dd4f69f64row0_col1 {
#             background-color:  #3182bd;
#             color:  #000000;
#         }    #T_3c76b56c_c78f_11eb_bf51_c83dd4f69f64row0_col2 {
#             background-color:  #3182bd;
#             color:  #000000;
#         }    #T_3c76b56c_c78f_11eb_bf51_c83dd4f69f64row0_col3 {
#             background-color:  #3182bd;
#             color:  #000000;
#         }    #T_3c76b56c_c78f_11eb_bf51_c83dd4f69f64row0_col4 {
#             background-color:  #3182bd;
#             color:  #000000;
#         }    #T_3c76b56c_c78f_11eb_bf51_c83dd4f69f64row0_col5 {
#             background-color:  #3182bd;
#             color:  #000000;
# ...

# %% [markdown]
#  Comments after exploring data::
